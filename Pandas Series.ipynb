# %% [markdown]
# # Pandas Series

# %%
import numpy as np
import pandas as pd

# %%
obj=pd.Series([4,7,-5,3])
print(obj)
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
import pandas as pd

obj = pd.Series([4, 7, -5, 3], index=['d', 'b', 'a', 'c'])

print(obj)
print(obj['a'])

obj['d'] = 6
print(obj)
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64
# -5
# d    6
# b    7
# a   -5
# c    3
# dtype: int64

# %%
print(obj[obj>0])
# Out:
# d    6
# b    7
# c    3
# dtype: int64

# %%
obj*2
# Out:
# d    12
# b    14
# a   -10
# c     6
# dtype: int64

# %%
import numpy as np
import pandas as pd

obj = pd.Series([4, 7, -5, 3], index=['d', 'b', 'a', 'c'])

result = np.exp(obj)
print(result)
# Out:
# d      54.598150
# b    1096.633158
# a       0.006738
# c      20.085537
# dtype: float64

# %%
'e' in obj
# Out:
# False

# %%
'b' in obj
# Out:
# True

# %%
sdata={'ohio':35000,'texas':71000,'oxgeon':16000,'utan':5000}
obj3=pd.Series(sdata)
print(obj3)
# Out:
# ohio      35000
# texas     71000
# oxgeon    16000
# utan       5000
# dtype: int64

# %%
states=['califorini',"ohio",'texas','orgeon']
obj4=pd.Series(sdata,index=states)
print(obj4)
# Out:
# califorini        NaN
# ohio          35000.0
# texas         71000.0
# orgeon            NaN
# dtype: float64

# %%
pd.isnull(obj4)
# Out:
# califorini     True
# ohio          False
# texas         False
# orgeon         True
# dtype: bool
